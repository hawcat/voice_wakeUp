# %%
import soundfile as sf

# %%
data1, sample_rate1 = sf.read("dataset/max/max_97.wav")
data2, sample_rate2 = sf.read("dataset/max_central/max_97.wav")
# data2, sample_rate2 = sf.read("dataset/max_central/max_1.wav")
print(data1, len(data1), sample_rate1)
print(data2, len(data2), sample_rate2)
# Out:
# [-9.15527344e-05 -3.66210938e-04 -3.66210938e-04 ... -2.13623047e-04
#  -2.74658203e-04 -6.10351562e-05] 32640 16000
# [0. 0. 0. ... 0. 0. 0.] 16000 16000

# %%
import matplotlib.pyplot as plt

# %%
fig, (ax1, ax2) = plt.subplots(2,1,sharex=True,sharey=True)
ax1.plot(data1)
ax2.plot(data2)

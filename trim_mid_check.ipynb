# %%
# !pip install soundfile
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# ...

# %%
import soundfile as sf

# %%
data1, sample_rate1 = sf.read("speech_commands_v0.02/max_trimed/max_1_central.wav")
data2, sample_rate2 = sf.read("speech_commands_v0.02/max_trimed/max_1_left.wav")
data3, sample_rate3 = sf.read("speech_commands_v0.02/max_trimed/max_1_right.wav")
# data2, sample_rate2 = sf.read("dataset/max_central/max_1.wav")
print(data1, len(data1), sample_rate1)
print(data2, len(data2), sample_rate2)
print(data3, len(data3), sample_rate3)
# Out:
# [0. 0. 0. ... 0. 0. 0.] 16000 16000
# [0.00057983 0.00057983 0.00109863 ... 0.         0.         0.        ] 16000 16000
# [0.         0.         0.         ... 0.00741577 0.00662231 0.00701904] 16000 16000

# %%
import matplotlib.pyplot as plt

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3,1,sharex=True,sharey=True)
ax1.plot(data1)
ax2.plot(data2)
ax3.plot(data3)
